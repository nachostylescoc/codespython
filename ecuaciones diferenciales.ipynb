# %% [markdown]
# # Ecuaciones diferenciales de primer orden

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# $\begin{equation}
# \frac{dy}{dt} = -2y + sen(t)
# \end{equation}$

# %%
# Definimos la ecuación diferencial
def dydt(t,y):
    return -2*y + np.sin(t)

# Intervalo y condiciones iniciales
tspan = np.array([0,1])
y0 = np.array([0])

# Solver (RK4)
sol = solve_ivp(dydt, tspan, y0, max_step=0.01)

# Grafico
plt.figure(figsize=(5,4))
plt.plot(sol.t, sol.y[0])
#plt.grid(True)
plt.show()
